# %% [markdown]
# <a href="https://massstreetuniversity.com/"><img src="http://tutorials.massstreetuniversity.com/images/logo.png" alt="School Logo"></a><br><br><br>
# <a href="http://tutorials.massstreetuniversity.com/transact-sql/">Tutorial Home</a>

# %% [markdown]
# <h1>Looping</h1>

# %% [markdown]
# You can process in loops using the WHILE statement. In 20 years, I think I have used WHILE ONCE. I can usually find a better solution than using WHILE.

# %% [markdown]
# <h1>Examples</h1>

# %% [markdown]
# <strong>Incrementing An Index Value</strong>

# %%
USE demo

DECLARE @i TINYINT = 1

WHILE @i < 10 BEGIN
PRINT 'The variable''s value is ' + CAST(@i AS NVARCHAR(1)) + '.'
SET @i = @i + 1
END

# %% [markdown]
# Copyright © 2020, Mass Street Analytics, LLC. All Rights Reserved.
